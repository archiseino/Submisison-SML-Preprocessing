# %% [markdown]
# # **1. Perkenalan Dataset**
#
# Name: Arsyadana Estu Aziz

# %% [markdown]
# Tahap pertama, Anda harus mencari dan menggunakan dataset dengan ketentuan sebagai berikut:
#
# 1. **Sumber Dataset**:
#    Dataset merupakan dataset yang tersedia dari [Kaggle](https://www.kaggle.com/datasets/prevek18/ames-housing-dataset) yang sangat cocok untuk tugas regressi seperti prediksi harga rumah dari beberapa kriteria. Dataset ini sangat cocok untuk submission kali ini

# %% [markdown]
# # **2. Import Library**

# %% [markdown]
# Pada tahap ini, Anda perlu mengimpor beberapa pustaka (library) Python yang dibutuhkan untuk analisis data dan pembangunan model machine learning atau deep learning.

# %%
## Importing Libraries 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk
import missingno as msno
import seaborn as sns

# %% [markdown]
# # **3. Memuat Dataset**

# %% [markdown]
# Pada tahap ini, Anda perlu memuat dataset ke dalam notebook. Jika dataset dalam format CSV, Anda bisa menggunakan pustaka pandas untuk membacanya. Pastikan untuk mengecek beberapa baris awal dataset untuk memahami strukturnya dan memastikan data telah dimuat dengan benar.
#
# Jika dataset berada di Google Drive, pastikan Anda menghubungkan Google Drive ke Colab terlebih dahulu. Setelah dataset berhasil dimuat, langkah berikutnya adalah memeriksa kesesuaian data dan siap untuk dianalisis lebih lanjut.
#
# Jika dataset berupa unstructured data, silakan sesuaikan dengan format seperti kelas Machine Learning Pengembangan atau Machine Learning Terapan

# %%
# Importing the dataset
df = pd.read_csv('../AmesHousing_raw.csv')

# %% [markdown]
# ### Dokumentasi Fitur Dataset Ames Housing
#
# | No. | Nama Fitur       | Tipe Data | Deskripsi Singkat |
# |-----|------------------|-----------|-------------------|
# | 0   | Id               | int64     | Identifikasi unik properti |
# | 1   | MSSubClass       | int64     | Kelas tipe bangunan yang terlibat dalam penjualan |
# | 2   | MSZoning         | object    | Klasifikasi zonasi umum penjualan |
# | 3   | LotFrontage      | float64   | Panjang depan properti yang terhubung ke jalan (dalam kaki) |
# | 4   | LotArea          | int64     | Ukuran lot dalam kaki persegi |
# | 5   | Street           | object    | Jenis akses jalan ke properti |
# | 6   | Alley            | object    | Jenis akses gang ke properti |
# | 7   | LotShape         | object    | Bentuk umum properti |
# | 8   | LandContour      | object    | Ketinggian tanah properti |
# | 9   | Utilities        | object    | Jenis utilitas yang tersedia |
# | 10  | LotConfig        | object    | Konfigurasi lot |
# | 11  | LandSlope        | object    | Kemiringan properti |
# | 12  | Neighborhood     | object    | Lokasi fisik dalam batas kota Ames |
# | 13  | Condition1       | object    | Kedekatan dengan jalan utama atau rel kereta api |
# | 14  | Condition2       | object    | Kedekatan kedua dengan jalan utama atau rel kereta api (jika ada) |
# | 15  | BldgType         | object    | Tipe bangunan |
# | 16  | HouseStyle       | object    | Gaya rumah |
# | 17  | OverallQual      | int64     | Kualitas material dan finishing secara keseluruhan |
# | 18  | OverallCond      | int64     | Kondisi keseluruhan rumah |
# | 19  | YearBuilt        | int64     | Tahun konstruksi asli |
# | 20  | YearRemodAdd     | int64     | Tahun renovasi atau penambahan |
# | 21  | RoofStyle        | object    | Jenis atap |
# | 22  | RoofMatl         | object    | Material atap |
# | 23  | Exterior1st      | object    | Material eksterior utama |
# | 24  | Exterior2nd      | object    | Material eksterior kedua |
# | 25  | MasVnrType       | object    | Jenis veneer batu |
# | 26  | MasVnrArea       | float64   | Luas veneer batu dalam kaki persegi |
# | 27  | ExterQual        | object    | Kualitas material eksterior |
# | 28  | ExterCond        | object    | Kondisi material eksterior |
# | 29  | Foundation       | object    | Jenis fondasi |
# | 30  | BsmtQual         | object    | Kualitas basement |
# | 31  | BsmtCond         | object    | Kondisi basement |
# | 32  | BsmtExposure     | object    | Paparan basement (walkout atau garden level) |
# | 33  | BsmtFinType1     | object    | Kualitas area basement yang selesai tipe 1 |
# | 34  | BsmtFinSF1       | int64     | Luas selesai basement tipe 1 dalam kaki persegi |
# | 35  | BsmtFinType2     | object    | Kualitas area basement yang selesai tipe 2 |
# | 36  | BsmtFinSF2       | int64     | Luas selesai basement tipe 2 dalam kaki persegi |
# | 37  | BsmtUnfSF        | int64     | Luas basement yang belum selesai dalam kaki persegi |
# | 38  | TotalBsmtSF      | int64     | Total luas basement dalam kaki persegi |
# | 39  | Heating          | object    | Jenis pemanas |
# | 40  | HeatingQC        | object    | Kualitas dan kondisi pemanas |
# | 41  | CentralAir       | object    | Apakah ada pendingin udara sentral |
# | 42  | Electrical       | object    | Sistem kelistrikan |
# | 43  | 1stFlrSF         | int64     | Luas lantai pertama dalam kaki persegi |
# | 44  | 2ndFlrSF         | int64     | Luas lantai kedua dalam kaki persegi |
# | 45  | LowQualFinSF     | int64     | Luas selesai berkualitas rendah dalam kaki persegi |
# | 46  | GrLivArea        | int64     | Luas area tinggal di atas tanah dalam kaki persegi |
# | 47  | BsmtFullBath     | int64     | Jumlah kamar mandi penuh di basement |
# | 48  | BsmtHalfBath     | int64     | Jumlah kamar mandi setengah di basement |
# | 49  | FullBath         | int64     | Jumlah kamar mandi penuh di atas tanah |
# | 50  | HalfBath         | int64     | Jumlah kamar mandi setengah di atas tanah |
# | 51  | BedroomAbvGr     | int64     | Jumlah kamar tidur di atas tanah |
# | 52  | KitchenAbvGr     | int64     | Jumlah dapur di atas tanah |
# | 53  | KitchenQual      | object    | Kualitas dapur |
# | 54  | TotRmsAbvGrd     | int64     | Total jumlah ruangan di atas tanah (tidak termasuk kamar mandi) |
# | 55  | Functional       | object    | Fungsi rumah |
# | 56  | Fireplaces       | int64     | Jumlah perapian |
# | 57  | FireplaceQu      | object    | Kualitas perapian |
# | 58  | GarageType       | object    | Lokasi garasi |
# | 59  | GarageYrBlt      | float64   | Tahun garasi dibangun |
# | 60  | GarageFinish     | object    | Finishing interior garasi |
# | 61  | GarageCars       | int64     | Kapasitas garasi dalam jumlah mobil |
# | 62  | GarageArea       | int64     | Luas garasi dalam kaki persegi |
# | 63  | GarageQual       | object    | Kualitas garasi |
# | 64  | GarageCond       | object    | Kondisi garasi |
# | 65  | PavedDrive       | object    | Apakah jalan masuk beraspal |
# | 66  | WoodDeckSF       | int64     | Luas dek kayu dalam kaki persegi |
# | 67  | OpenPorchSF      | int64     | Luas teras terbuka dalam kaki persegi |
# | 68  | EnclosedPorch    | int64     | Luas teras tertutup dalam kaki persegi |
# | 69  | 3SsnPorch        | int64     | Luas teras tiga musim dalam kaki persegi |
# | 70  | ScreenPorch      | int64     | Luas teras berlayar dalam kaki persegi |
# | 71  | PoolArea         | int64     | Luas kolam renang dalam kaki persegi |
# | 72  | PoolQC           | object    | Kualitas kolam renang |
# | 73  | Fence            | object    | Kualitas pagar |
# | 74  | MiscFeature      | object    | Fitur tambahan lainnya |
# | 75  | MiscVal          | int64     | Nilai fitur tambahan lainnya |
# | 76  | MoSold           | int64     | Bulan penjualan |
# | 77  | YrSold           | int64     | Tahun penjualan |
# | 78  | SaleType         | object    | Jenis penjualan |
# | 79  | SaleCondition    | object    | Kondisi penjualan |
# | 80  | SalePrice        | int64     | Harga jual properti (target variabel) |

# %% [markdown]
# # **4. Exploratory Data Analysis (EDA)**
#
# Pada tahap ini, Anda akan melakukan **Exploratory Data Analysis (EDA)** untuk memahami karakteristik dataset.
#
# Tujuan dari EDA adalah untuk memperoleh wawasan awal yang mendalam mengenai data dan menentukan langkah selanjutnya dalam analisis atau pemodelan.

# %% [markdown]
# ### Checking the dataset with the Head(), Info() and Describe()
#
# Checking the dataset to see the content and the distributions

# %%
## Checking the dataset with the first 5 rows
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
## Checking the shape of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
## Checking the dataset with describe()
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %% [markdown]
# ### Target Variable Distribution
#
# Melihat distribusi target variable SalePrice apakah sudah terdistribusi secara normal

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of SalePrice
plt.figure(figsize=(8, 4))
sns.histplot(df['SalePrice'], kde=True, color='skyblue')
plt.title('Distribusi Harga Rumah (SalePrice)')
plt.xlabel('SalePrice')
plt.ylabel('Jumlah Rumah')
plt.show()

# Check skewness
df['SalePrice'].skew()
# Out:
# 1.7435000757376466

# %% [markdown]
# ### Correlation with Target
#
# Melihat korelasi antar data numerik dengan variabel target untuk proses data preprocessing

# %%
# Correlation matrix with target
corr = df.corr(numeric_only=True)
top_corr = corr['SalePrice'].sort_values(ascending=False).head(15)

plt.figure(figsize=(6, 4))
sns.barplot(x=top_corr.values, y=top_corr.index, palette='viridis')
plt.title('Fitur dengan Korelasi Tertinggi terhadap SalePrice')
plt.xlabel('Korelasi')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_8312\3946674900.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_corr.values, y=top_corr.index, palette='viridis')

# %% [markdown]
# ### Feature types summary
#
# Melihat total statistik data dan missing values dari masing-masing features numerik dan kategorikal

# %%
# Visualize missing values
msno.matrix(df)
msno.bar(df)
# Out:
# <Axes: >

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

print("Jumlah fitur numerik:", len(numerical_cols))
print("Jumlah fitur kategorikal:", len(categorical_cols))
# Out:
# Jumlah fitur numerik: 39
# Jumlah fitur kategorikal: 43

# %% [markdown]
# ### Insight Awal dari EDA
#
# - SalePrice menunjukkan distribusi right-skewed → kemungkinan butuh log-transform.
# - Fitur seperti OverallQual dan GrLivArea memiliki korelasi tinggi dengan SalePrice.
# - Banyak fitur memiliki missing values, seperti PoolQC, Alley, dan FireplaceQu → perlu strategi imputasi.
# - Ada lebih dari 40 fitur kategorikal, sebagian besar memerlukan encoding (label/one-hot).

# %% [markdown]
# # **5. Data Preprocessing**

# %% [markdown]
# Pada tahap ini, data preprocessing adalah langkah penting untuk memastikan kualitas data sebelum digunakan dalam model machine learning.
#
# Jika Anda menggunakan data teks, data mentah sering kali mengandung nilai kosong, duplikasi, atau rentang nilai yang tidak konsisten, yang dapat memengaruhi kinerja model. Oleh karena itu, proses ini bertujuan untuk membersihkan dan mempersiapkan data agar analisis berjalan optimal.
#
# Berikut adalah tahapan-tahapan yang bisa dilakukan, tetapi **tidak terbatas** pada:
# 1. Menghapus atau Menangani Data Kosong (Missing Values)
# 2. Menghapus Data Duplikat
# 3. Normalisasi atau Standarisasi Fitur
# 4. Deteksi dan Penanganan Outlier
# 5. Encoding Data Kategorikal
# 6. Binning (Pengelompokan Data)
#
# Cukup sesuaikan dengan karakteristik data yang kamu gunakan yah. Khususnya ketika kami menggunakan data tidak terstruktur.

# %%
## Calculate the percentage of missing values for each column
missing_percentage = df.isnull().mean() * 100

# Filter columns with more than 50% missing values
high_missing_cols = missing_percentage[missing_percentage > 50].index.tolist()
print("Kolom dengan lebih dari 50% nilai yang hilang:", high_missing_cols)
# Out:
# Kolom dengan lebih dari 50% nilai yang hilang: ['Alley', 'Mas Vnr Type', 'Pool QC', 'Fence', 'Misc Feature']

# %%
## Drop columns with more than 50% missing values
df.drop(columns=high_missing_cols, inplace=True)

## Drop the ID columns
df.drop(columns=["Order", "PID"], inplace=True)

# %%
## Check duplicates
duplicates = df.duplicated().sum()
print("Jumlah duplikat dalam dataset:", duplicates)
# Out:
# Jumlah duplikat dalam dataset: 0

# %%
## Scaling numerical features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
## Defined the categorical features for Ordinal Encoding for the feature that has the order, and One-Hot Encoding for the rest
ordinal_cols = ['Exter Qual', 'Exter Cond', 'Bsmt Qual', 'Bsmt Cond', 'Heating QC', 'Kitchen Qual', 'Fireplace Qu', 'Garage Qual', 'Garage Cond']
one_hot_cols = df.select_dtypes(include=['object']).columns.tolist()

from sklearn.preprocessing import LabelEncoder, OneHotEncoder

## Encoding the ordinal features
ordinal_encoder = LabelEncoder()
for col in ordinal_cols:
    df[col] = ordinal_encoder.fit_transform(df[col].astype(str))

## Encoding the categorical features with One-Hot Encoding
one_hot_encoder = OneHotEncoder(sparse_output=False, drop='first')
one_hot_encoded = one_hot_encoder.fit_transform(df[one_hot_cols])
# Create a DataFrame for the one-hot encoded features
one_hot_df = pd.DataFrame(one_hot_encoded, columns=one_hot_encoder.get_feature_names_out(one_hot_cols))

# Concatenate the one-hot encoded features with the original DataFrame
df = pd.concat([df.drop(columns=one_hot_cols), one_hot_df], axis=1)

# %%
## Feature Engineering: Create new features based on existing ones
df["House Age"] = df["Yr Sold"] - df["Year Built"]

## Final check of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Columns: 228 entries, MS SubClass to House Age
# dtypes: float64(219), int32(9)
# memory usage: 5.0 MB

# %%
## Export the cleaned dataset
df.to_csv('AmesHousing_preprocessing.csv', index=False)
